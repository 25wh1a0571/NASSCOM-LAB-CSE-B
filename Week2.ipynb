# %%
try:
  x=int(input("enter a number"))
  print(x)
except ValueError:
  print("Invalid number")
# Out:
# enter a numbergsfdhg
# Invalid number

# %%
try:
  x=int(input("enter a number"))
  result=100/x
except ValueError:
  print("Invalid number")
except ZeroDivisionError:
  print("Cant divide with zero")
else:
  print("Result is:",result)
finally:
  print("Code block exceuted")
# Out:
# enter a number0
# Cant divide with zero
# Code block exceuted

# %%
from collections import namedtuple
info=namedtuple('Info','Name Phone city')
p1=info("Pranavi",9392522,"HNR")
print(p1)
# Out:
# Info(Name='Pranavi', Phone=9392522, city='HNR')

# %%
try:
    a = int("ten")
    b = 10 / 0
except (ValueError, ZeroDivisionError) as e:
    print("An error occurred:", e)
# Out:
# An error occurred: invalid literal for int() with base 10: 'ten'

# %%
def check_age(age):
    if age < 0:
        raise ValueError("Age cannot be negative!")
    else:
        print("Age is valid.")

try:
    check_age(-10)
except ValueError as e:
    print("Caught an exception:", e)
# Out:
# Caught an exception: Age cannot be negative!

# %%
def divide(a, b):
    print(f"Dividing {a} by {b}")
    return a / b

print(divide(10, 2))
# Out:
# Dividing 10 by 2
# 5.0

# %%
import traceback

try:
    result = 10 / 0
except Exception as e:
    print("Something went wrong.")
    traceback.print_exc()
# Out:
# Something went wrong.
# Traceback (most recent call last):
#   File "/tmp/ipykernel_1204/142134494.py", line 4, in <cell line: 0>
#     result = 10 / 0
#              ~~~^~~
# ZeroDivisionError: division by zero
