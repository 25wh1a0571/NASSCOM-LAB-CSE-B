# %% [markdown]
# Input and Output formatted functions

# %%
print("Hello World")
# Out:
# Hello World

# %%
name=int(input("Enter age"))
# Out:
# Enter age17

# %%
name="Pranavi"
age=17
print(f"Name:{name}")
print(f"Age:{age}")
# Out:
# Name:Pranavi
# Age:17

# %%
name="Pranavi"
age=17

print("Student Name: {}".format(name))
print("Age: {}".format(age))
# Out:
# Student Name: Pranavi
# Age: 17

# %%
name="Pranavi"
age=17
print("Name:%s"%name)
print("Age:%d"%age)
# Out:
# Name:Pranavi
# Age:17

# %%
print("welcome to python")
# Out:
# welcome to python

# %%
print(25)
print(50)
# Out:
# 25
# 50

# %%
name="Rahul"
print(name)
# Out:
# Rahul

# %%
a=10
b=15
print(a,b)
# Out:
# 10 15

# %%
a=20
b=4
print(a)
print(b)
# Out:
# 20
# 4

# %%
a = 20
b = 3
print (a,b)
# Out:
# 20 3

# %%
name = "Anjali"
age = 19
print(name,age)
# Out:
# Anjali 19

# %%
name="Priya"
print(f"Name:{name}")
# Out:
# Name:Priya

# %%
city="Hyderabad"
print("City: {}".format(city))
# Out:
# City: Hyderabad

# %%
name="Kiran"
print("Name:%s"%name)
# Out:
# Name:Kiran

# %%
a = 5
b = 4
print(a,b)
# Out:
# 5 4

# %%
x = 2
print(x)
# Out:
# 2

# %%
num = 25
print(num)
# Out:
# 25

# %%
value = 15.522222
print(type(value))
print(f"Value: {value:.2f}")
# Out:
# <class 'float'>
# Value: 15.52

# %%
name = "Asha"
marks = 92
print(f"Name:{name}")
print(f"Marks:{marks}")
# Out:
# Name:Asha
# Marks:92

# %%
print("Python", "Programming", "language")
# Out:
# Python Programming language

# %%
a = 10
b = 20
print("Sum =", a + b)
# Out:
# Sum = 30

# %%
name = "Rahul"
print(name * 3)
# Out:
# RahulRahulRahul

# %%
age = input("Enter Age: ")
# Out:
# Enter Age: 17

# %%
x = 10
y = 20
print(f"x:{x} y:{y}")
# Out:
# x:10 y:20

# %%
name = "Amit"
cgpa = 8.75
print(name,cgpa)
# Out:
# Amit 8.75

# %%
def greet():
    print("Hello! Welcome to Python Functions.")
greet()
# Out:
# Hello! Welcome to Python Functions.

# %%
def greet_user(name):
    print(f"Hello, {name}!")

greet_user("Pranavi")
greet_user("Sharanya")
# Out:
# Hello, Pranavi!
# Hello, Sharanya!

# %%
def greet_user(name="Guest"):
  print(f"Hello,{name}!!")

greet_user()
greet_user("Pranavi")
# Out:
# Hello,Guest!!
# Hello,Pranavi!!

# %%
def greet_user(*names):
  for name in names:
    print(f"Hello ,{name}!!")

greet_user("pranavi","sharnya","xyz")
# Out:
# Hello ,pranavi!!
# Hello ,sharnya!!
# Hello ,xyz!!

# %%
def greet_user(**details):
  for key,value in details.items():
    print(f"{key}={value}")

greet_user(Name="Pranavi",Age=17,College="BVRITH")
# Out:
# Name=Pranavi
# Age=17
# College=BVRITH

# %%
def show_details(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)

show_details(1, 2, 3, name="Ravi", city="Mumbai")
# Out:
# Args: (1, 2, 3)
# Kwargs: {'name': 'Ravi', 'city': 'Mumbai'}

# %%
def multiply(a, b):
    return a * b

def square(n):
    return multiply(n, n)

print("Square of 4:", square(4))
# Out:
# Square of 4: 16

# %%
def multiply(a):
  return a*2
x=map(multiply,(1,2,3))
print(list(x))
# Out:
# [2, 4, 6]

# %%
numbers=[1,2,3,4]
even_numbers=list(filter(lambda x:x%2==0,numbers))
square=list(map(lambda x:x*x,even_numbers))
print(square)
# Out:
# [4, 16]

# %%
from functools import reduce
numbers=[1,2,3,4,5]
reduced=reduce(lambda x,y:x+y,numbers)
print(reduced)
# Out:
# 15

# %%
info = {"marks1": 92, "marks2": 72, "marks3": 45}
new_info=dict(map(lambda item:(item[0],item[1]+3),info.items()))

print(new_info)
# Out:
# {'marks1': 95, 'marks2': 75, 'marks3': 48}

# %%
info = {"marks1": 92, "marks2": 72, "marks3": 45}
passed=dict(filter(lambda item:item[1]>50,info.items()))
print(passed)
# Out:
# {'marks1': 92, 'marks2': 72}

# %%
from functools import reduce
info = {"marks1": 92, "marks2": 72, "marks3": 45}
total=reduce(lambda a,b:a+b,info.values())
print(total)
# Out:
# 209
